# %% [markdown]
# <a href="https://colab.research.google.com/github/IevgenTs/uoft-ml-3253-assignments/blob/main/module-05-model-training-feature-selection/module_05_model_training_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment for Module 5, Training Models
#
# In this assignment you will train different models on a given data set, and find the one that performs best

# %% [markdown]
# ### Getting the data for the assignment (similar to the notebook from chapter 2 of Hands-On...)

# %%
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()

# %% [markdown]
# ## Checking Data Structure

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
housing.shape
# Out:
# (20640, 10)

# %%
# # extra code – code to save the figures as high-res PNGs for the book

# IMAGES_PATH = Path() / "images" / "end_to_end_project"
# IMAGES_PATH.mkdir(parents=True, exist_ok=True)

# def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
#     path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
#     if tight_layout:
#         plt.tight_layout()
#     plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import matplotlib.pyplot as plt

# extra code – the next 5 lines define the default font sizes
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

housing.hist(bins=50, figsize=(12, 8))
# save_fig("attribute_histogram_plots")  # extra code
plt.show()

# %% [markdown]
# ### Fix the categories in the categorical variable

# %%
d = {'<1H OCEAN':'LESS_1H_OCEAN', 'INLAND':'INLAND', 'ISLAND':'ISLAND', 'NEAR BAY':'NEAR_BAY', 'NEAR OCEAN':'NEAR_OCEAN'}
housing['ocean_proximity'] = housing['ocean_proximity'].map(lambda s: d[s])

# %%
housing.head ()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR_BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR_BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR_BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR_BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR_BAY

# %% [markdown]
# ### Add 2 more features

# %%
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["population_per_household"]=housing["population"]/housing["households"]

# %% [markdown]
# ### Fix missing data

# %%
median = housing["total_bedrooms"].median()
housing["total_bedrooms"].fillna(median, inplace=True)
# Out:
# <ipython-input-62-11ec5b3165b1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing["total_bedrooms"].fillna(median, inplace=True)

# %% [markdown]
# ### Create dummy variables based on the categorical variable

# %%
one_hot = pd.get_dummies(housing['ocean_proximity'])
housing = housing.drop('ocean_proximity', axis=1)
housing = housing.join(one_hot)

# %% [markdown]
# ### Check the data

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 20640 non-null  float64
#  1   latitude                  20640 non-null  float64
#  2   housing_median_age        20640 non-null  float64
#  3   total_rooms               20640 non-null  float64
#  4   total_bedrooms            20640 non-null  float64
#  5   population                20640 non-null  float64
#  6   households                20640 non-null  float64
#  7   median_income             20640 non-null  float64
#  8   median_house_value        20640 non-null  float64
#  9   rooms_per_household       20640 non-null  float64
#  10  population_per_household  20640 non-null  float64
#  11  INLAND                    20640 non-null  bool
#  12  ISLAND                    20640 non-null  bool
#  13  LESS_1H_OCEAN             20640 non-null  bool
#  14  NEAR_BAY                  20640 non-null  bool
#  15  NEAR_OCEAN                20640 non-null  bool
# dtypes: bool(5), float64(11)
# memory usage: 1.8 MB

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    rooms_per_household  population_per_household  INLAND  ISLAND  \
# 0             6.984127                  2.555556   False   False
# 1             6.238137                  2.109842   False   False
# 2             8.288136                  2.802260   False   False
# 3             5.817352                  2.547945   False   False
# 4             6.281853                  2.181467   False   False
#
#    LESS_1H_OCEAN  NEAR_BAY  NEAR_OCEAN
# 0          False      True       False
# 1          False      True       False
# 2          False      True       False
# 3          False      True       False
# 4          False      True       False

# %% [markdown]
# # ASSIGNMENT

# %% [markdown]
# ### 1. Partition into train and test
#
# Use train_test_split from sklearn.model_selection to partition the dataset into 70% for training and 30% for testing.
#
# You can use the 70% for training set as both training and validation by using cross-validation.

# %%
from sklearn.model_selection import train_test_split
#train_set, test_set = ## YOUR CODE HERE ##
train_set, test_set = train_test_split(housing, test_size=0.3, random_state=42)

# %% [markdown]
# ### Features

# %%
#Separating data into:
#The variable you are trying to predict (the target).
#The variables you will use to make the prediction (the features).

target = 'median_house_value'
features = list(train_set.columns)
features = [f for f in features if f!=target]

# %%
X_tr = train_set[features]
y_tr = train_set[[target]]

X_te = test_set[features]
y_te = test_set[[target]]

# %%
print(X_tr.shape)
print(X_te.shape)
# Out:
# (14448, 15)
# (6192, 15)

# %%
from re import X
# print(X_tr)
# print(y_te.shape)
X_tr.head()
X_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14448 entries, 7061 to 15795
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 14448 non-null  float64
#  1   latitude                  14448 non-null  float64
#  2   housing_median_age        14448 non-null  float64
#  3   total_rooms               14448 non-null  float64
#  4   total_bedrooms            14448 non-null  float64
#  5   population                14448 non-null  float64
#  6   households                14448 non-null  float64
#  7   median_income             14448 non-null  float64
#  8   rooms_per_household       14448 non-null  float64
#  9   population_per_household  14448 non-null  float64
#  10  INLAND                    14448 non-null  bool
#  11  ISLAND                    14448 non-null  bool
#  12  LESS_1H_OCEAN             14448 non-null  bool
#  13  NEAR_BAY                  14448 non-null  bool
#  14  NEAR_OCEAN                14448 non-null  bool
# dtypes: bool(5), float64(10)
# memory usage: 1.3 MB

# %% [markdown]
# ### 2. Polynomial transformations

# %% [markdown]
# Use PolynomialFeatures from sklearn.preprocessing

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2)
poly.fit(X_tr)
X_tr = poly.transform(X_tr)
X_te = poly.transform(X_te)

# %%
#Wrong code

# from sklearn.preprocessing import PolynomialFeatures
# poly = PolynomialFeatures(degree=2, include_bias=False)
# X_tr = poly.fit_transform(X_tr)
# X_te = poly.transform(X_te)

# %%
print(X_tr.shape)
print(X_te.shape)
# Out:
# (14448, 136)
# (6192, 136)

# %% [markdown]
# ##### You should obtain X_tr and X_te with 136 columns each, since originally you had 15 features.
#
# ##### With m original features, the new added polynomial features of degree 2 are: $(m^2-m)/2+m+1$. Why?
#
# ##### These, plus the original features gives a total of  $(m^2-m)/2+2m+1$

# %%
print("Original number of features: "+str(len(features)))
print("Final number of features: "+str(X_tr.shape[1]))
# Out:
# Original number of features: 15
# Final number of features: 136

# %% [markdown]
# ### 3. Scaling features

# %% [markdown]
# Similarly, use StandardScaler from sklearn.preprocessing to normalize the training and testing data, using the training data

# %%
from sklearn.preprocessing import StandardScaler
# Initialize the StandardScaler
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Fit and transform the training features (X_tr)
X_tr_scaled = scaler_X.fit_transform(X_tr)
# Fit and transform the training target (y_tr)
y_tr_scaled = scaler_y.fit_transform(y_tr)


# Transform test features (X_te)
X_te_scaled = scaler_X.transform(X_te)
# Transform test target (y_te)
y_te_scaled = scaler_y.transform(y_te)

# %%
print(X_tr_scaled.shape)
# Out:
# (14448, 136)

# %% [markdown]
# #### Comparing models

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import numpy as np

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())

# %% [markdown]
# ### 4. Linear regression on original features (no transformations) --- benchmark
#
# #### Your goal is to find the model that minimizes the rmse score

# %%
from sklearn.linear_model import LinearRegression
lin_scores = cross_val_score(LinearRegression(), train_set[features], train_set[target], scoring="neg_mean_squared_error", cv=4)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [70142.55721218 67456.39127204 67318.3258893  70866.26065275]
# Mean: 68945.8837565685

# %%
pd.Series(lin_rmse_scores).describe()
# Out:
# count        4.000000
# mean     68945.883757
# std       1824.591941
# min      67318.325889
# 25%      67421.874926
# 50%      68799.474242
# 75%      70323.483072
# max      70866.260653
# dtype: float64

# %% [markdown]
# ### 5. Linear regression  (on transformed features: polynomial transformation + scaling)

# %% [markdown]
# Now do as in 4 but with the original and transformed features (136 features)

# %%
#Linear regression after polyminominal transformation and data scaling/transformation
lin_scores = cross_val_score(LinearRegression(), X_tr_scaled, y_tr, scoring="neg_mean_squared_error", cv=4)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [139670.35757836 316779.09083701 518543.6462032  137711.77296417]
# Mean: 278176.2168956847

# %%
pd.Series(lin_rmse_scores).describe()
# Out:
# count         4.000000
# mean     278176.216896
# std      180905.883470
# min      137711.772964
# 25%      139180.711425
# 50%      228224.724208
# 75%      367220.229679
# max      518543.646203
# dtype: float64

# %% [markdown]
# If the error on the cross-validation is too high it is because the model is over-fitting. Regularization is needed.

# %% [markdown]
# ### 6. Ridge regression

# %%
from sklearn.linear_model import Ridge
param_grid = [{'alpha': [0.001,0.01,0.1,1,10,100,1000,10000]}]
grid_search_rr = GridSearchCV(Ridge(), param_grid, cv=3, scoring='neg_mean_squared_error')
grid_search_rr.fit(X_tr_scaled, y_tr)
# Out:
# GridSearchCV(cv=3, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000,
#                                     10000]}],
#              scoring='neg_mean_squared_error')

# %%
print(grid_search_rr.best_params_)
print(np.sqrt(-grid_search_rr.best_score_))
# Out:
# {'alpha': 1000}
# 67204.15300429484

# %% [markdown]
# ### 7. Lasso regression
#
# Now do the same as in 6 but with Lasso

# %%
from sklearn.linear_model import Lasso
param_grid = [{'alpha': [0.001,0.01,0.1,1,10,100,1000,10000]}]
grid_search_lasso = GridSearchCV(Lasso(), param_grid, cv=3, scoring='neg_mean_squared_error')
grid_search_lasso.fit(X_tr_scaled, y_tr)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.898e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.864e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.897e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.863e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.892e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.892e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.857e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.835e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.797e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.488e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.290e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.350e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.201e+12, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.254e+12, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=3, estimator=Lasso(),
#              param_grid=[{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000,
#                                     10000]}],
#              scoring='neg_mean_squared_error')

# %%
print(grid_search_lasso.best_params_)
print(np.sqrt(-grid_search_lasso.best_score_))
# Out:
# {'alpha': 1000}
# 66619.6312718291

# %%
grid_search_lasso.best_params_
# Out:
# {'alpha': 1000}

# %%
grid_search_lasso.best_estimator_
# Out:
# Lasso(alpha=1000)

# %% [markdown]
# ### 8. Elastic Net regression
#
# Do the same as in 6 and 7, but now with Elastic Net. However, the grid search should be over the parameters alpha and  l 1ratio. Use just 3 values for l1_ratio.

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV

param_grid = [
    {
        'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000],
        'l1_ratio': [0.2, 0.4, 0.6]
    }
]

grid_search_elasticnet = GridSearchCV(ElasticNet(), param_grid, cv=3, scoring='neg_mean_squared_error')
grid_search_elasticnet.fit(X_tr_scaled, y_tr)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.920e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.941e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.888e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.915e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.936e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.884e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.910e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.929e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.879e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.996e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.022e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.966e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.981e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.007e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.951e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.963e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.988e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.933e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.188e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.224e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.161e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.153e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.181e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.125e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.110e+13, tolerance: 1.292e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.139e+13, tolerance: 1.290e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.079e+13, tolerance: 1.289e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.236e+13, tolerance: 1.936e+10
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=3, estimator=ElasticNet(),
#              param_grid=[{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000],
#                           'l1_ratio': [0.2, 0.4, 0.6]}],
#              scoring='neg_mean_squared_error')

# %%
print(grid_search_elasticnet.best_params_)
print(np.sqrt(-grid_search_elasticnet.best_score_))
# Out:
# {'alpha': 0.1, 'l1_ratio': 0.4}
# 67072.67698457319

# %% [markdown]
# ### Evaluating your best model on TESTING data
#
# Choose among grid_search_rr, grid_search_lr, and grid_search_enr, the model with best performance

# %%
from sklearn.metrics import mean_squared_error

final_model = grid_search_lasso.best_estimator_   ## grid_search SHOULD BE THE BEST GRID SEARCH ##

y_te_estimation = final_model.predict(X_te_scaled)

final_mse = mean_squared_error(y_te_scaled, y_te_estimation)
final_rmse = np.sqrt(final_mse)
print(final_rmse)
# Out:
# 225722.0603042761

# %%
print("y_tr mean:", np.mean(y_tr), "y_tr std:", np.std(y_tr))
print("y_te mean:", np.mean(y_te), "y_te std:", np.std(y_te))
# Out:
# y_tr mean: 206923.9608942414 y_tr std: median_house_value    115745.23651
# dtype: float64
# y_te mean: 206696.8142764858 y_te std: median_house_value    114566.142809
# dtype: float64
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
import matplotlib.pyplot as plt

plt.scatter(x=y_te, y=y_te_estimation)
plt.xlim([-200000,800000])
plt.ylim([-200000,800000])
plt.show()

# %% [markdown]
# ### Question: Before you computed the final_rmse on the test data, what was your expected value for this quantity? Does your best model have high variance?

# %% [markdown]
# ##### YOUR ANSWER HERE

# %% [markdown]
# #[Optional]
# Why does the matrix X appears transponsed in the normal equation in the linear regression? Equation 4.4. Start from equation 4.3

# %% [markdown]
# #[Optional]
# Do all Gradient Descent algorithms lead to the same model provided you let them run long enough?

# %% [markdown]
# #[Optional]
# Is it a good idea to stop Mini-batch Gradient Descent immediately when the validation error goes up?

# %% [markdown]
# #[Optional]
# Suppose you are using Ridge Regression and you notice that the training error and the validation error are almost equal and fairly high. Would you say that the model suffers from high bias or high variance? Should you increase the regularization hyperparameter α or reduce it?

# %% [markdown]
# #[Optional]
# Why does the matrix X appears transponsed in the normal equation in the linear regression? Equation 4.4. Start from equation 4.3
